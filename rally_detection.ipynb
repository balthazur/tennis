# %%
# %pip install inference supervision inference_sdk --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import supervision as sv
from inference import get_model, InferencePipeline
from tqdm import tqdm

# %%
file_name = "demo_alt_10fps"
file_extension = ".mp4"
source_path = f"videos/{file_name}{file_extension}"
api_key = "" # API KEY
ball_detection_model_id = "tennis-ball-detection-e5vmz/16" #"tennis-ball-detection-e5vmz/15"
api_url = "http://127.0.0.1:9001" # use local inference server

# %%
ball_detector = get_model(model_id=ball_detection_model_id, api_key=api_key)

# %%
from inference_sdk import InferenceHTTPClient
CLIENT = InferenceHTTPClient(
    api_url="http://localhost:9001",
    api_key=api_key
)

image_url = "https://source.roboflow.com/pwYAXv9BTpqLyFfgQoPZ/u48G0UpWfk8giSw7wrU8/original.jpg"
result = CLIENT.infer(image_url, model_id="soccer-players-5fuqs/1")
print(result)
# Out:
# {'inference_id': '7eaec277-7484-4bb9-b804-395d0529998d', 'time': 0.10833283399551874, 'image': {'width': 398, 'height': 224}, 'predictions': [{'x': 5.0, 'y': 152.0, 'width': 10.0, 'height': 28.0, 'confidence': 0.8946052193641663, 'class': 'player', 'class_id': 1, 'detection_id': '2307aa31-8fc9-48af-b717-f10b78785eb2'}, {'x': 145.0, 'y': 95.5, 'width': 14.0, 'height': 25.0, 'confidence': 0.8900073766708374, 'class': 'player', 'class_id': 1, 'detection_id': '26ea721e-84e0-4868-99e2-d4907aae68fb'}, {'x': 25.0, 'y': 89.5, 'width': 16.0, 'height': 25.0, 'confidence': 0.8871816396713257, 'class': 'player', 'class_id': 1, 'detection_id': 'ea3a19ce-f30c-4335-a79d-5ea42fb6c0f4'}, {'x': 313.0, 'y': 178.0, 'width': 16.0, 'height': 32.0, 'confidence': 0.87803715467453, 'class': 'player', 'class_id': 1, 'detection_id': 'c6486bbc-335a-4e12-95d4-a704d46f996d'}, {'x': 324.0, 'y': 106.5, 'width': 12.0, 'height': 25.0, 'confidence': 0.8769770264625549, 'class': 'player', 'class_id': 1, 'detection_id': 'a9f37c8b-6a16-4ab1-b389-9c4fa8214b1f'}, {'x': 44.0, 'y': 63.5, 'width': 12.0, 'height': 21.0, 'confidence': 0.8717014789581299, 'class': 'player', 'class_id': 1, 'detection_id': '67227c8f-febb-4e02-8f12-774912563671'}, {'x': 114.0, 'y': 105.0, 'width': 14.0, 'height': 22.0, 'confidence': 0.8648115396499634, 'class': 'player', 'class_id': 1, 'detection_id': '1141a4d7-da17-4c83-b2df-93c96207cfdd'}, {'x': 216.0, 'y': 113.0, 'width': 14.0, 'height': 26.0, 'confidence': 0.8561445474624634, 'class': 'player', 'class_id': 1, 'detection_id': 'dc1ea5a3-15a4-45b9-947e-672d8922c0d1'}, {'x': 329.5, 'y': 84.5, 'width': 13.0, 'height': 23.0, 'confidence': 0.8458843231201172, 'class': 'player', 'class_id': 1, 'detection_id': 'e6414685-48f3-46fd-8bbb-004a10224f45'}, {'x': 106.0, 'y': 88.0, 'width': 12.0, 'height': 20.0, 'confidence': 0.8435384035110474, 'class': 'player', 'class_id': 1, 'detection_id': 'dcb43239-c269-4873-924c-f9e766ef54ca'}, {'x': 159.0, 'y': 156.0, 'width': 14.0, 'height': 28.0, 'confidence': 0.8411979675292969, 'class': 'player', 'class_id': 1, 'detection_id': '872ccd54-b9db-40cc-8ef2-08e967ebbd25'}, {'x': 203.5, 'y': 74.5, 'width': 11.0, 'height': 19.0, 'confidence': 0.8406029343605042, 'class': 'player', 'class_id': 1, 'detection_id': 'c759e58d-fd6b-4c57-8765-d3949aafae5f'}, {'x': 170.5, 'y': 49.5, 'width': 13.0, 'height': 19.0, 'confidence': 0.8320416212081909, 'class': 'player', 'class_id': 1, 'detection_id': '7b3f4bbe-a9c6-41f4-bd1e-383049f7f3f8'}, {'x': 298.0, 'y': 45.5, 'width': 12.0, 'height': 17.0, 'confidence': 0.8220680356025696, 'class': 'player', 'class_id': 1, 'detection_id': '131a5f25-6441-4443-a8ac-74b00865fcc5'}, {'x': 188.5, 'y': 91.5, 'width': 11.0, 'height': 21.0, 'confidence': 0.8184288740158081, 'class': 'player', 'class_id': 1, 'detection_id': 'db3c9157-b006-4eb4-b9e2-5d5cd36c53e1'}, {'x': 161.5, 'y': 55.0, 'width': 11.0, 'height': 18.0, 'confidence': 0.8015870451927185, 'class': 'player', 'class_id': 1, 'detection_id': 'a4c94277-8a25-4a91-84e2-a8aa5438c490'}, {'x': 168.0, 'y': 147.0, 'width': 16.0, 'height': 22.0, 'confidence': 0.7936298847198486, 'class': 'player', 'class_id': 1, 'detection_id': '6ee7c2ff-8bca-4aca-bf8f-5433d5279dea'}, {'x': 3.0, 'y': 116.0, 'width': 6.0, 'height': 28.0, 'confidence': 0.7491620779037476, 'class': 'player', 'class_id': 1, 'detection_id': '8cba6bb3-2052-4276-94c4-79c73fd14303'}, {'x': 394.0, 'y': 60.0, 'width': 8.0, 'height': 26.0, 'confidence': 0.7033823728561401, 'class': 'player', 'class_id': 1, 'detection_id': 'b8ce76ea-650d-4c2e-9847-bea0e5679c76'}, {'x': 180.5, 'y': 110.5, 'width': 9.0, 'height': 25.0, 'confidence': 0.6400018334388733, 'class': 'player', 'class_id': 1, 'detection_id': '138e50ce-c840-4e31-9be5-bc6380a65c60'}]}

# %%
from inference_sdk import InferenceHTTPClient, InferenceConfiguration
import cv2
import numpy as np
import supervision as sv

custom_configuration = InferenceConfiguration(confidence_threshold=0.15)

client = InferenceHTTPClient(
    api_url="http://localhost:9001",
    api_key=api_key
)

client.configure(custom_configuration)

def infer_toss(image):
    toss_predictions = client.run_workflow(
        workspace_name="tennis-rally-detection",
        workflow_id="detect-toss",
        images={
            "image": image,
        }
    )
    return toss_predictions

def infer_ball(image):
    ball_predictions = client.infer(
        image,
        model_id=ball_detection_model_id,
        
    )
    return ball_predictions

def ball_detection_callback(image_slice: np.ndarray) -> sv.Detections:
    # Use the existing infer_ball function
    predictions = infer_ball(image_slice)
    
    # Convert predictions to sv.Detections format
    detections = sv.Detections.from_inference(predictions)
    return detections

ball_slicer = sv.InferenceSlicer(callback=ball_detection_callback)

# %%
import supervision as sv

video_info = sv.VideoInfo.from_video_path(video_path=source_path)

total_frames = video_info.total_frames
frame_number = 0


results = []

progress_bar = tqdm(total=total_frames, desc="Processing frames")

for frame in sv.get_video_frames_generator(source_path=source_path):
    toss_predictions = infer_toss(frame)
    ball_predictions = ball_slicer(frame)
    frame_number += 1
    progress_bar.update(1)
    results.append((toss_predictions, ball_predictions))
progress_bar.close()
# toss:
# [{'output': [{'time': 0.33360033300004943, 'image': {'width': 65, 'height': 109}, 'predictions': [{'class': 'other', 'class_id': 1, 'confidence': 0.9926}, {'class': 'toss', 'class_id': 0, 'confidence': 0.0074}], 'top': 'other', 'confidence': 0.9926, 'prediction_type': 'classification', 'parent_id': 'ced0e87d-2bd5-420d-be0c-66c145699be7', 'root_parent_id': 'image'}, {'time': 0.3336179580001044, 'image': {'width': 102, 'height': 152}, 'predictions': [{'class': 'other', 'class_id': 1, 'confidence': 0.9939}, {'class': 'toss', 'class_id': 0, 'confidence': 0.0061}], 'top': 'other', 'confidence': 0.9939, 'prediction_type': 'classification', 'parent_id': '627ce165-92d3-4070-996b-ca7adf4f2d1c', 'root_parent_id': 'image'}]}]

# ball:
#{'inference_id': '64347833-556d-4ba2-881e-48d508a8d3ca', 'time': 0.33276966599987645, 'image': {'width': 1280, 'height': 720}, 'predictions': [{'x': 710.0, 'y': 178.0, 'width': 6.0, 'height': 6.0, 'confidence': 0.6501944661140442, 'class': 'tennis-ball', 'class_id': 0, 'detection_id': '9d96a56e-6207-4bbb-abd8-02ab846e1f6e'}]}
# Out:
# Processing frames:   0%|          | 0/499 [00:00<?, ?it/s]
# Processing frames: 100%|██████████| 499/499 [18:20<00:00,  2.21s/it]

# %%
def getTossResult(toss_predictions):
    if not toss_predictions:
        return False
    for output in toss_predictions:
        if not isinstance(output, dict) or 'output' not in output:
            continue
        for prediction in output['output']:
            if isinstance(prediction, dict) and prediction.get('top') == 'toss':
                return True
    return False

toss_results = []
ball_results = []
player_detections = []

for toss_predictions, ball_predictions in results:
    # Always append a boolean value, even if predictions are None
    toss_results.append(getTossResult(toss_predictions))
    #ball_results.append(len([pred for pred in ball_predictions.get('predictions', []) if pred['class'] == 'tennis-ball']))
    ball_results.append(len(ball_predictions.class_id))

    player_detections.append(sv.Detections.from_inference(toss_predictions["predictions_player"]))

print(f"Frames with toss detected: {sum(toss_results)}")
print(f"Frames with ball detected: {sum(ball_results)}")

print(f"Total frames processed: {len(toss_results)}")
print(f"Toss results length: {len(toss_results)}")
print(f"Ball results length: {len(ball_results)}")

AFTER_TOSS_THRESHOLD = 20

NO_BALL_THRESHOLD = 6
no_ball_end_signal = [False] * len(ball_results)
for i in range(4, len(ball_results)):
    if all(ball_results[j] == 0 for j in range(i-NO_BALL_THRESHOLD, i+1)) and not any(toss_results[j] for j in range(max(0, i-AFTER_TOSS_THRESHOLD), i+1)):
        no_ball_end_signal[i] = True

# Define the threshold for multiple balls
MULTIPLE_BALL_THRESHOLD = 2
MIN_HITS = 5
FRAMES_WINDOW = 6

multiple_ball_end_signal = [False] * len(ball_results)
for i in range(FRAMES_WINDOW - 1, len(ball_results)):
    # Count frames with 2 or more balls in the last 6 frames (including current)
    multiple_ball_count = sum(1 for j in range(i-FRAMES_WINDOW+1, i+1) if ball_results[j] >= MULTIPLE_BALL_THRESHOLD)
    print(f"Frame {i}: Multiple ball count: {multiple_ball_count}")
    
    # Check if there's no toss in the last 5 frames
    no_toss = not any(toss_results[j] for j in range(i-AFTER_TOSS_THRESHOLD, i+1))
    
    # Set the end signal if at least 3 out of 5 frames have multiple balls and there's no recent toss
    if multiple_ball_count >= MIN_HITS and no_toss:
        multiple_ball_end_signal[i] = True




# Print all results
print("\nAll results:")
for i in range(len(toss_results)):
    print(f"Frame {i}: | T: {toss_results[i]}, B: {ball_results[i]} | End signals: {no_ball_end_signal[i]} {multiple_ball_end_signal[i]}")
# Out:
# Frames with toss detected: 2
# Frames with ball detected: 614
# Total frames processed: 499
# Toss results length: 499
# Ball results length: 499
# Frame 5: Multiple ball count: 0
# Frame 6: Multiple ball count: 0
# Frame 7: Multiple ball count: 0
# Frame 8: Multiple ball count: 0
# Frame 9: Multiple ball count: 0
# Frame 10: Multiple ball count: 0
# Frame 11: Multiple ball count: 0
# Frame 12: Multiple ball count: 0
# Frame 13: Multiple ball count: 0
# Frame 14: Multiple ball count: 0
# Frame 15: Multiple ball count: 0
# Frame 16: Multiple ball count: 0
# Frame 17: Multiple ball count: 0
# Frame 18: Multiple ball count: 0
# Frame 19: Multiple ball count: 0
# Frame 20: Multiple ball count: 1
# Frame 21: Multiple ball count: 1
# Frame 22: Multiple ball count: 1
# Frame 23: Multiple ball count: 1
# Frame 24: Multiple ball count: 1
# Frame 25: Multiple ball count: 1
# Frame 26: Multiple ball count: 0
# Frame 27: Multiple ball count: 0
# Frame 28: Multiple ball count: 0
# Frame 29: Multiple ball count: 0
# Frame 30: Multiple ball count: 0
# Frame 31: Multiple ball count: 0
# Frame 32: Multiple ball count: 0
# Frame 33: Multiple ball count: 0
# Frame 34: Multiple ball count: 0
# Frame 35: Multiple ball count: 0
# Frame 36: Multiple ball count: 0
# Frame 37: Multiple ball count: 0
# Frame 38: Multiple ball count: 0
# Frame 39: Multiple ball count: 0
# Frame 40: Multiple ball count: 0
# Frame 41: Multiple ball count: 0
# Frame 42: Multiple ball count: 0
# Frame 43: Multiple ball count: 0
# Frame 44: Multiple ball count: 0
# Frame 45: Multiple ball count: 1
# Frame 46: Multiple ball count: 1
# Frame 47: Multiple ball count: 1
# Frame 48: Multiple ball count: 1
# Frame 49: Multiple ball count: 1
# Frame 50: Multiple ball count: 1
# Frame 51: Multiple ball count: 0
# Frame 52: Multiple ball count: 0
# Frame 53: Multiple ball count: 0
# Frame 54: Multiple ball count: 0
# Frame 55: Multiple ball count: 0
# Frame 56: Multiple ball count: 0
# Frame 57: Multiple ball count: 0
# Frame 58: Multiple ball count: 0
# Frame 59: Multiple ball count: 0
# Frame 60: Multiple ball count: 0
# Frame 484: Multiple ball count: 6
# Frame 485: Multiple ball count: 6
# Frame 486: Multiple ball count: 6
# Frame 487: Multiple ball count: 5
# Frame 488: Multiple ball count: 5
# Frame 489: Multiple ball count: 5
# Frame 490: Multiple ball count: 5
# Frame 491: Multiple ball count: 5
# Frame 492: Multiple ball count: 5
# Frame 493: Multiple ball count: 5
# Frame 494: Multiple ball count: 5
# Frame 495: Multiple ball count: 5
# Frame 496: Multiple ball count: 5
# Frame 497: Multiple ball count: 4
# Frame 498: Multiple ball count: 4
#
# All results:
# Frame 0: | T: False, B: 1 | End signals: False False
# Frame 1: | T: False, B: 1 | End signals: False False
# Frame 2: | T: False, B: 1 | End signals: False False
# Frame 3: | T: False, B: 1 | End signals: False False
# Frame 4: | T: False, B: 0 | End signals: False False
# Frame 5: | T: False, B: 0 | End signals: False False
# Frame 6: | T: False, B: 0 | End signals: False False
# Frame 7: | T: False, B: 0 | End signals: False False
# Frame 8: | T: False, B: 0 | End signals: False False
# Frame 9: | T: False, B: 0 | End signals: False False
# Frame 10: | T: False, B: 0 | End signals: True False
# Frame 11: | T: False, B: 0 | End signals: True False
# Frame 12: | T: False, B: 0 | End signals: True False
# Frame 13: | T: False, B: 1 | End signals: False False
# Frame 14: | T: False, B: 0 | End signals: False False
# Frame 15: | T: False, B: 1 | End signals: False False
# Frame 16: | T: True, B: 1 | End signals: False False
# Frame 17: | T: False, B: 1 | End signals: False False
# Frame 18: | T: False, B: 1 | End signals: False False
# Frame 19: | T: False, B: 1 | End signals: False False
# Frame 20: | T: False, B: 2 | End signals: False False
# Frame 21: | T: False, B: 1 | End signals: False False
# Frame 22: | T: False, B: 1 | End signals: False False
# Frame 23: | T: False, B: 1 | End signals: False False
# Frame 24: | T: False, B: 1 | End signals: False False
# Frame 25: | T: False, B: 1 | End signals: False False
# Frame 26: | T: False, B: 1 | End signals: False False
# Frame 27: | T: False, B: 1 | End signals: False False
# Frame 28: | T: False, B: 1 | End signals: False False
# Frame 29: | T: False, B: 0 | End signals: False False
# Frame 30: | T: False, B: 0 | End signals: False False
# Frame 31: | T: False, B: 1 | End signals: False False
# Frame 32: | T: False, B: 0 | End signals: False False
# Frame 33: | T: False, B: 0 | End signals: False False
# Frame 34: | T: False, B: 0 | End signals: False False
# Frame 35: | T: False, B: 1 | End signals: False False
# Frame 36: | T: False, B: 0 | End signals: False False
# Frame 37: | T: False, B: 1 | End signals: False False
# Frame 38: | T: False, B: 1 | End signals: False False
# Frame 39: | T: False, B: 1 | End signals: False False
# Frame 40: | T: False, B: 1 | End signals: False False
# Frame 41: | T: False, B: 0 | End signals: False False
# Frame 42: | T: False, B: 1 | End signals: False False
# Frame 43: | T: False, B: 1 | End signals: False False
# Frame 44: | T: False, B: 1 | End signals: False False
# Frame 45: | T: False, B: 2 | End signals: False False
# Frame 46: | T: False, B: 1 | End signals: False False
# Frame 47: | T: False, B: 1 | End signals: False False
# Frame 48: | T: False, B: 1 | End signals: False False
# Frame 49: | T: False, B: 1 | End signals: False False
# Frame 50: | T: False, B: 1 | End signals: False False
# Frame 51: | T: False, B: 0 | End signals: False False
# Frame 52: | T: False, B: 1 | End signals: False False
# Frame 53: | T: False, B: 1 | End signals: False False
# Frame 54: | T: False, B: 1 | End signals: False False
# Frame 55: | T: False, B: 1 | End signals: False False
# Frame 56: | T: False, B: 0 | End signals: False False
# Frame 57: | T: False, B: 1 | End signals: False False
# Frame 58: | T: False, B: 0 | End signals: False False
# Frame 59: | T: False, B: 0 | End signals: False False
# Frame 60: | T: False, B: 1 | End signals: False False
# Frame 61: | T: False, B: 1 | End signals: False False
# Frame 62: | T: False, B: 0 | End signals: False False
# Frame 63: | T: False, B: 1 | End signals: False False
# Frame 64: | T: False, B: 0 | End signals: False False
# Frame 65: | T: False, B: 0 | End signals: False False
# Frame 66: | T: False, B: 1 | End signals: False False
# Frame 67: | T: False, B: 1 | End signals: False False
# Frame 68: | T: False, B: 1 | End signals: False False
# Frame 69: | T: False, B: 1 | End signals: False False
# Frame 70: | T: False, B: 1 | End signals: False False
# Frame 71: | T: False, B: 0 | End signals: False False
# Frame 72: | T: False, B: 2 | End signals: False False
# Frame 73: | T: False, B: 1 | End signals: False False
# Frame 74: | T: False, B: 1 | End signals: False False
# Frame 75: | T: False, B: 1 | End signals: False False
# Frame 76: | T: False, B: 1 | End signals: False False
# Frame 77: | T: False, B: 1 | End signals: False False
# Frame 78: | T: False, B: 1 | End signals: False False
# Frame 79: | T: False, B: 1 | End signals: False False
# Frame 80: | T: False, B: 1 | End signals: False False
# Frame 81: | T: False, B: 1 | End signals: False False
# Frame 82: | T: False, B: 0 | End signals: False False
# Frame 83: | T: False, B: 0 | End signals: False False
# Frame 84: | T: False, B: 1 | End signals: False False
# Frame 85: | T: False, B: 0 | End signals: False False
# Frame 86: | T: False, B: 0 | End signals: False False
# Frame 87: | T: False, B: 1 | End signals: False False
# Frame 88: | T: False, B: 1 | End signals: False False
# Frame 89: | T: False, B: 2 | End signals: False False
# Frame 90: | T: False, B: 1 | End signals: False False
# Frame 91: | T: False, B: 1 | End signals: False False
# Frame 92: | T: False, B: 1 | End signals: False False
# Frame 93: | T: False, B: 0 | End signals: False False
# Frame 94: | T: False, B: 1 | End signals: False False
# Frame 95: | T: False, B: 0 | End signals: False False
# Frame 96: | T: False, B: 0 | End signals: False False
# Frame 97: | T: False, B: 0 | End signals: False False
# Frame 98: | T: False, B: 0 | End signals: False False
# Frame 99: | T: False, B: 0 | End signals: False False
# Frame 100: | T: False, B: 1 | End signals: False False
# Frame 101: | T: False, B: 0 | End signals: False False
# Frame 102: | T: False, B: 1 | End signals: False False
# Frame 103: | T: False, B: 1 | End signals: False False
# Frame 104: | T: False, B: 1 | End signals: False False
# Frame 105: | T: False, B: 1 | End signals: False False
# Frame 106: | T: False, B: 1 | End signals: False False
# Frame 107: | T: False, B: 1 | End signals: False False
# Frame 108: | T: False, B: 0 | End signals: False False
# Frame 109: | T: False, B: 1 | End signals: False False
# Frame 110: | T: False, B: 1 | End signals: False False
# Frame 111: | T: False, B: 0 | End signals: False False
# Frame 112: | T: False, B: 1 | End signals: False False
# Frame 113: | T: False, B: 1 | End signals: False False
# Frame 114: | T: False, B: 1 | End signals: False False
# Frame 115: | T: False, B: 1 | End signals: False False
# Frame 116: | T: False, B: 1 | End signals: False False
# Frame 117: | T: False, B: 2 | End signals: False False
# Frame 118: | T: False, B: 2 | End signals: False False
# Frame 119: | T: False, B: 0 | End signals: False False
# Frame 120: | T: False, B: 1 | End signals: False False
# Frame 121: | T: False, B: 0 | End signals: False False
# Frame 122: | T: False, B: 0 | End signals: False False
# Frame 123: | T: False, B: 0 | End signals: False False
# Frame 124: | T: False, B: 0 | End signals: False False
# Frame 125: | T: False, B: 0 | End signals: False False
# Frame 126: | T: False, B: 0 | End signals: False False
# Frame 127: | T: False, B: 1 | End signals: False False
# Frame 128: | T: False, B: 0 | End signals: False False
# Frame 129: | T: False, B: 0 | End signals: False False
# Frame 130: | T: False, B: 1 | End signals: False False
# Frame 131: | T: False, B: 1 | End signals: False False
# Frame 132: | T: False, B: 1 | End signals: False False
# Frame 133: | T: False, B: 1 | End signals: False False
# Frame 134: | T: False, B: 0 | End signals: False False
# Frame 135: | T: False, B: 1 | End signals: False False
# Frame 136: | T: False, B: 1 | End signals: False False
# Frame 137: | T: False, B: 1 | End signals: False False
# Frame 138: | T: False, B: 2 | End signals: False False
# Frame 139: | T: False, B: 2 | End signals: False False
# Frame 140: | T: False, B: 2 | End signals: False False
# Frame 141: | T: False, B: 1 | End signals: False False
# Frame 142: | T: False, B: 2 | End signals: False False
# Frame 143: | T: False, B: 2 | End signals: False True
# Frame 144: | T: False, B: 2 | End signals: False True
# Frame 145: | T: False, B: 1 | End signals: False False
# Frame 146: | T: False, B: 1 | End signals: False False
# Frame 147: | T: False, B: 1 | End signals: False False
# Frame 148: | T: False, B: 1 | End signals: False False
# Frame 149: | T: False, B: 1 | End signals: False False
# Frame 150: | T: False, B: 1 | End signals: False False
# Frame 151: | T: False, B: 2 | End signals: False False
# Frame 152: | T: False, B: 1 | End signals: False False
# Frame 153: | T: False, B: 1 | End signals: False False
# Frame 154: | T: False, B: 2 | End signals: False False
# Frame 155: | T: False, B: 2 | End signals: False False
# Frame 156: | T: False, B: 2 | End signals: False False
# Frame 157: | T: False, B: 1 | End signals: False False
# Frame 158: | T: False, B: 1 | End signals: False False
# Frame 159: | T: False, B: 2 | End signals: False False
# Frame 160: | T: False, B: 2 | End signals: False False
# Frame 161: | T: False, B: 2 | End signals: False False
# Frame 162: | T: False, B: 3 | End signals: False False
# Frame 163: | T: False, B: 3 | End signals: False True
# Frame 164: | T: False, B: 3 | End signals: False True
# Frame 165: | T: False, B: 2 | End signals: False True
# Frame 166: | T: False, B: 2 | End signals: False True
# Frame 167: | T: False, B: 2 | End signals: False True
# Frame 168: | T: False, B: 1 | End signals: False True
# Frame 169: | T: False, B: 1 | End signals: False False
# Frame 170: | T: False, B: 1 | End signals: False False
# Frame 171: | T: False, B: 1 | End signals: False False
# Frame 172: | T: False, B: 1 | End signals: False False
# Frame 173: | T: False, B: 2 | End signals: False False
# Frame 174: | T: False, B: 3 | End signals: False False
# Frame 175: | T: False, B: 1 | End signals: False False
# Frame 176: | T: False, B: 3 | End signals: False False
# Frame 177: | T: False, B: 1 | End signals: False False
# Frame 178: | T: False, B: 2 | End signals: False False
# Frame 179: | T: False, B: 2 | End signals: False False
# Frame 180: | T: False, B: 3 | End signals: False False
# Frame 181: | T: False, B: 1 | End signals: False False
# Frame 182: | T: False, B: 2 | End signals: False False
# Frame 183: | T: False, B: 1 | End signals: False False
# Frame 184: | T: False, B: 2 | End signals: False False
# Frame 185: | T: False, B: 2 | End signals: False False
# Frame 186: | T: False, B: 3 | End signals: False False
# Frame 187: | T: False, B: 1 | End signals: False False
# Frame 188: | T: False, B: 3 | End signals: False False
# Frame 189: | T: False, B: 3 | End signals: False True
# Frame 190: | T: False, B: 4 | End signals: False True
# Frame 191: | T: False, B: 2 | End signals: False True
# Frame 192: | T: False, B: 2 | End signals: False True
# Frame 193: | T: False, B: 2 | End signals: False True
# Frame 194: | T: False, B: 3 | End signals: False True
# Frame 195: | T: False, B: 3 | End signals: False True
# Frame 196: | T: False, B: 2 | End signals: False True
# Frame 197: | T: False, B: 0 | End signals: False True
# Frame 198: | T: False, B: 2 | End signals: False True
# Frame 199: | T: False, B: 4 | End signals: False True
# Frame 200: | T: False, B: 3 | End signals: False True
# Frame 201: | T: False, B: 3 | End signals: False True
# Frame 202: | T: False, B: 3 | End signals: False True
# Frame 203: | T: False, B: 2 | End signals: False True
# Frame 204: | T: False, B: 2 | End signals: False True
# Frame 205: | T: False, B: 2 | End signals: False True
# Frame 206: | T: False, B: 1 | End signals: False True
# Frame 207: | T: False, B: 1 | End signals: False False
# Frame 208: | T: False, B: 1 | End signals: False False
# Frame 209: | T: False, B: 1 | End signals: False False
# Frame 210: | T: False, B: 1 | End signals: False False
# Frame 211: | T: False, B: 3 | End signals: False False
# Frame 212: | T: False, B: 3 | End signals: False False
# Frame 213: | T: False, B: 4 | End signals: False False
# Frame 214: | T: False, B: 0 | End signals: False False
# Frame 215: | T: False, B: 0 | End signals: False False
# Frame 216: | T: False, B: 0 | End signals: False False
# Frame 217: | T: False, B: 0 | End signals: False False
# Frame 218: | T: False, B: 1 | End signals: False False
# Frame 219: | T: False, B: 1 | End signals: False False
# Frame 220: | T: False, B: 0 | End signals: False False
# Frame 221: | T: False, B: 0 | End signals: False False
# Frame 222: | T: False, B: 1 | End signals: False False
# Frame 223: | T: False, B: 1 | End signals: False False
# Frame 224: | T: False, B: 1 | End signals: False False
# Frame 225: | T: False, B: 1 | End signals: False False
# Frame 226: | T: False, B: 1 | End signals: False False
# Frame 227: | T: False, B: 0 | End signals: False False
# Frame 228: | T: False, B: 2 | End signals: False False
# Frame 229: | T: False, B: 1 | End signals: False False
# Frame 230: | T: False, B: 1 | End signals: False False
# Frame 231: | T: False, B: 2 | End signals: False False
# Frame 232: | T: False, B: 2 | End signals: False False
# Frame 233: | T: False, B: 1 | End signals: False False
# Frame 234: | T: False, B: 2 | End signals: False False
# Frame 235: | T: False, B: 2 | End signals: False False
# Frame 236: | T: False, B: 2 | End signals: False True
# Frame 237: | T: False, B: 3 | End signals: False True
# Frame 238: | T: False, B: 3 | End signals: False True
# Frame 239: | T: False, B: 1 | End signals: False True
# Frame 240: | T: False, B: 1 | End signals: False False
# Frame 241: | T: False, B: 2 | End signals: False False
# Frame 242: | T: False, B: 0 | End signals: False False
# Frame 243: | T: False, B: 0 | End signals: False False
# Frame 244: | T: False, B: 1 | End signals: False False
# Frame 245: | T: False, B: 1 | End signals: False False
# Frame 246: | T: False, B: 1 | End signals: False False
# Frame 247: | T: False, B: 2 | End signals: False False
# Frame 248: | T: False, B: 2 | End signals: False False
# Frame 249: | T: False, B: 2 | End signals: False False
# Frame 250: | T: False, B: 3 | End signals: False False
# Frame 251: | T: False, B: 2 | End signals: False True
# Frame 252: | T: False, B: 1 | End signals: False True
# Frame 253: | T: False, B: 2 | End signals: False True
# Frame 254: | T: False, B: 3 | End signals: False True
# Frame 255: | T: False, B: 1 | End signals: False False
# Frame 256: | T: False, B: 2 | End signals: False False
# Frame 257: | T: False, B: 1 | End signals: False False
# Frame 258: | T: False, B: 2 | End signals: False False
# Frame 259: | T: False, B: 1 | End signals: False False
# Frame 260: | T: False, B: 1 | End signals: False False
# Frame 261: | T: False, B: 0 | End signals: False False
# Frame 262: | T: False, B: 0 | End signals: False False
# Frame 263: | T: False, B: 1 | End signals: False False
# Frame 264: | T: False, B: 1 | End signals: False False
# Frame 265: | T: False, B: 1 | End signals: False False
# Frame 266: | T: False, B: 1 | End signals: False False
# Frame 267: | T: False, B: 0 | End signals: False False
# Frame 268: | T: False, B: 1 | End signals: False False
# Frame 269: | T: False, B: 1 | End signals: False False
# Frame 270: | T: False, B: 1 | End signals: False False
# Frame 271: | T: False, B: 0 | End signals: False False
# Frame 272: | T: False, B: 1 | End signals: False False
# Frame 273: | T: False, B: 1 | End signals: False False
# Frame 274: | T: False, B: 1 | End signals: False False
# Frame 275: | T: False, B: 1 | End signals: False False
# Frame 276: | T: False, B: 1 | End signals: False False
# Frame 277: | T: False, B: 0 | End signals: False False
# Frame 278: | T: False, B: 1 | End signals: False False
# Frame 279: | T: False, B: 1 | End signals: False False
# Frame 280: | T: False, B: 2 | End signals: False False
# Frame 281: | T: False, B: 1 | End signals: False False
# Frame 282: | T: False, B: 1 | End signals: False False
# Frame 283: | T: False, B: 1 | End signals: False False
# Frame 284: | T: False, B: 1 | End signals: False False
# Frame 285: | T: False, B: 1 | End signals: False False
# Frame 286: | T: False, B: 0 | End signals: False False
# Frame 287: | T: False, B: 0 | End signals: False False
# Frame 288: | T: False, B: 0 | End signals: False False
# Frame 289: | T: False, B: 0 | End signals: False False
# Frame 290: | T: False, B: 0 | End signals: False False
# Frame 291: | T: False, B: 0 | End signals: False False
# Frame 292: | T: False, B: 0 | End signals: True False
# Frame 293: | T: False, B: 0 | End signals: True False
# Frame 294: | T: False, B: 0 | End signals: True False
# Frame 295: | T: False, B: 0 | End signals: True False
# Frame 296: | T: False, B: 0 | End signals: True False
# Frame 297: | T: False, B: 0 | End signals: True False
# Frame 298: | T: False, B: 0 | End signals: True False
# Frame 299: | T: False, B: 0 | End signals: True False
# Frame 300: | T: False, B: 1 | End signals: False False
# Frame 301: | T: False, B: 1 | End signals: False False
# Frame 302: | T: False, B: 1 | End signals: False False
# Frame 303: | T: False, B: 1 | End signals: False False
# Frame 304: | T: False, B: 1 | End signals: False False
# Frame 305: | T: False, B: 1 | End signals: False False
# Frame 306: | T: False, B: 1 | End signals: False False
# Frame 307: | T: False, B: 1 | End signals: False False
# Frame 308: | T: False, B: 1 | End signals: False False
# Frame 309: | T: False, B: 2 | End signals: False False
# Frame 310: | T: False, B: 0 | End signals: False False
# Frame 311: | T: False, B: 1 | End signals: False False
# Frame 312: | T: False, B: 1 | End signals: False False
# Frame 313: | T: False, B: 0 | End signals: False False
# Frame 314: | T: False, B: 1 | End signals: False False
# Frame 315: | T: False, B: 1 | End signals: False False
# Frame 316: | T: False, B: 1 | End signals: False False
# Frame 317: | T: False, B: 1 | End signals: False False
# Frame 318: | T: False, B: 0 | End signals: False False
# Frame 319: | T: False, B: 0 | End signals: False False
# Frame 320: | T: False, B: 0 | End signals: False False
# Frame 321: | T: False, B: 1 | End signals: False False
# Frame 322: | T: False, B: 1 | End signals: False False
# Frame 323: | T: False, B: 1 | End signals: False False
# Frame 324: | T: False, B: 1 | End signals: False False
# Frame 325: | T: False, B: 1 | End signals: False False
# Frame 326: | T: False, B: 1 | End signals: False False
# Frame 327: | T: False, B: 1 | End signals: False False
# Frame 328: | T: False, B: 1 | End signals: False False
# Frame 329: | T: False, B: 1 | End signals: False False
# Frame 330: | T: False, B: 1 | End signals: False False
# Frame 331: | T: False, B: 1 | End signals: False False
# Frame 332: | T: False, B: 0 | End signals: False False
# Frame 333: | T: False, B: 0 | End signals: False False
# Frame 334: | T: False, B: 0 | End signals: False False
# Frame 335: | T: False, B: 0 | End signals: False False
# Frame 336: | T: True, B: 1 | End signals: False False
# Frame 337: | T: False, B: 1 | End signals: False False
# Frame 338: | T: False, B: 1 | End signals: False False
# Frame 339: | T: False, B: 1 | End signals: False False
# Frame 340: | T: False, B: 1 | End signals: False False
# Frame 341: | T: False, B: 1 | End signals: False False
# Frame 342: | T: False, B: 1 | End signals: False False
# Frame 343: | T: False, B: 1 | End signals: False False
# Frame 344: | T: False, B: 1 | End signals: False False
# Frame 345: | T: False, B: 1 | End signals: False False
# Frame 346: | T: False, B: 1 | End signals: False False
# Frame 347: | T: False, B: 0 | End signals: False False
# Frame 348: | T: False, B: 0 | End signals: False False
# Frame 349: | T: False, B: 0 | End signals: False False
# Frame 350: | T: False, B: 1 | End signals: False False
# Frame 351: | T: False, B: 0 | End signals: False False
# Frame 352: | T: False, B: 0 | End signals: False False
# Frame 353: | T: False, B: 0 | End signals: False False
# Frame 354: | T: False, B: 1 | End signals: False False
# Frame 355: | T: False, B: 0 | End signals: False False
# Frame 356: | T: False, B: 0 | End signals: False False
# Frame 357: | T: False, B: 1 | End signals: False False
# Frame 358: | T: False, B: 0 | End signals: False False
# Frame 359: | T: False, B: 0 | End signals: False False
# Frame 360: | T: False, B: 1 | End signals: False False
# Frame 361: | T: False, B: 0 | End signals: False False
# Frame 362: | T: False, B: 1 | End signals: False False
# Frame 363: | T: False, B: 1 | End signals: False False
# Frame 364: | T: False, B: 1 | End signals: False False
# Frame 365: | T: False, B: 1 | End signals: False False
# Frame 366: | T: False, B: 0 | End signals: False False
# Frame 367: | T: False, B: 0 | End signals: False False
# Frame 368: | T: False, B: 1 | End signals: False False
# Frame 369: | T: False, B: 1 | End signals: False False
# Frame 370: | T: False, B: 1 | End signals: False False
# Frame 371: | T: False, B: 1 | End signals: False False
# Frame 372: | T: False, B: 2 | End signals: False False
# Frame 373: | T: False, B: 1 | End signals: False False
# Frame 374: | T: False, B: 2 | End signals: False False
# Frame 375: | T: False, B: 1 | End signals: False False
# Frame 376: | T: False, B: 1 | End signals: False False
# Frame 377: | T: False, B: 1 | End signals: False False
# Frame 378: | T: False, B: 1 | End signals: False False
# Frame 379: | T: False, B: 1 | End signals: False False
# Frame 380: | T: False, B: 1 | End signals: False False
# Frame 381: | T: False, B: 1 | End signals: False False
# Frame 382: | T: False, B: 1 | End signals: False False
# Frame 383: | T: False, B: 1 | End signals: False False
# Frame 384: | T: False, B: 1 | End signals: False False
# Frame 385: | T: False, B: 1 | End signals: False False
# Frame 386: | T: False, B: 1 | End signals: False False
# Frame 387: | T: False, B: 1 | End signals: False False
# Frame 388: | T: False, B: 1 | End signals: False False
# Frame 389: | T: False, B: 0 | End signals: False False
# Frame 390: | T: False, B: 2 | End signals: False False
# Frame 391: | T: False, B: 0 | End signals: False False
# Frame 392: | T: False, B: 1 | End signals: False False
# Frame 393: | T: False, B: 0 | End signals: False False
# Frame 394: | T: False, B: 2 | End signals: False False
# Frame 395: | T: False, B: 1 | End signals: False False
# Frame 396: | T: False, B: 2 | End signals: False False
# Frame 397: | T: False, B: 3 | End signals: False False
# Frame 398: | T: False, B: 1 | End signals: False False
# Frame 399: | T: False, B: 1 | End signals: False False
# Frame 400: | T: False, B: 1 | End signals: False False
# Frame 401: | T: False, B: 1 | End signals: False False
# Frame 402: | T: False, B: 1 | End signals: False False
# Frame 403: | T: False, B: 1 | End signals: False False
# Frame 404: | T: False, B: 1 | End signals: False False
# Frame 405: | T: False, B: 1 | End signals: False False
# Frame 406: | T: False, B: 1 | End signals: False False
# Frame 407: | T: False, B: 1 | End signals: False False
# Frame 408: | T: False, B: 0 | End signals: False False
# Frame 409: | T: False, B: 2 | End signals: False False
# Frame 410: | T: False, B: 1 | End signals: False False
# Frame 411: | T: False, B: 0 | End signals: False False
# Frame 412: | T: False, B: 1 | End signals: False False
# Frame 413: | T: False, B: 2 | End signals: False False
# Frame 414: | T: False, B: 2 | End signals: False False
# Frame 415: | T: False, B: 1 | End signals: False False
# Frame 416: | T: False, B: 1 | End signals: False False
# Frame 417: | T: False, B: 1 | End signals: False False
# Frame 418: | T: False, B: 1 | End signals: False False
# Frame 419: | T: False, B: 1 | End signals: False False
# Frame 420: | T: False, B: 1 | End signals: False False
# Frame 421: | T: False, B: 1 | End signals: False False
# Frame 422: | T: False, B: 1 | End signals: False False
# Frame 423: | T: False, B: 1 | End signals: False False
# Frame 424: | T: False, B: 2 | End signals: False False
# Frame 425: | T: False, B: 1 | End signals: False False
# Frame 426: | T: False, B: 1 | End signals: False False
# Frame 427: | T: False, B: 1 | End signals: False False
# Frame 428: | T: False, B: 2 | End signals: False False
# Frame 429: | T: False, B: 2 | End signals: False False
# Frame 430: | T: False, B: 3 | End signals: False False
# Frame 431: | T: False, B: 1 | End signals: False False
# Frame 432: | T: False, B: 2 | End signals: False False
# Frame 433: | T: False, B: 2 | End signals: False True
# Frame 434: | T: False, B: 2 | End signals: False True
# Frame 435: | T: False, B: 3 | End signals: False True
# Frame 436: | T: False, B: 3 | End signals: False True
# Frame 437: | T: False, B: 3 | End signals: False True
# Frame 438: | T: False, B: 3 | End signals: False True
# Frame 439: | T: False, B: 3 | End signals: False True
# Frame 440: | T: False, B: 3 | End signals: False True
# Frame 441: | T: False, B: 3 | End signals: False True
# Frame 442: | T: False, B: 3 | End signals: False True
# Frame 443: | T: False, B: 3 | End signals: False True
# Frame 444: | T: False, B: 3 | End signals: False True
# Frame 445: | T: False, B: 3 | End signals: False True
# Frame 446: | T: False, B: 2 | End signals: False True
# Frame 447: | T: False, B: 2 | End signals: False True
# Frame 448: | T: False, B: 2 | End signals: False True
# Frame 449: | T: False, B: 2 | End signals: False True
# Frame 450: | T: False, B: 2 | End signals: False True
# Frame 451: | T: False, B: 3 | End signals: False True
# Frame 452: | T: False, B: 3 | End signals: False True
# Frame 453: | T: False, B: 4 | End signals: False True
# Frame 454: | T: False, B: 3 | End signals: False True
# Frame 455: | T: False, B: 2 | End signals: False True
# Frame 456: | T: False, B: 2 | End signals: False True
# Frame 457: | T: False, B: 3 | End signals: False True
# Frame 458: | T: False, B: 3 | End signals: False True
# Frame 459: | T: False, B: 3 | End signals: False True
# Frame 460: | T: False, B: 2 | End signals: False True
# Frame 461: | T: False, B: 3 | End signals: False True
# Frame 462: | T: False, B: 2 | End signals: False True
# Frame 463: | T: False, B: 3 | End signals: False True
# Frame 464: | T: False, B: 2 | End signals: False True
# Frame 465: | T: False, B: 2 | End signals: False True
# Frame 466: | T: False, B: 2 | End signals: False True
# Frame 467: | T: False, B: 2 | End signals: False True
# Frame 468: | T: False, B: 3 | End signals: False True
# Frame 469: | T: False, B: 3 | End signals: False True
# Frame 470: | T: False, B: 3 | End signals: False True
# Frame 471: | T: False, B: 3 | End signals: False True
# Frame 472: | T: False, B: 3 | End signals: False True
# Frame 473: | T: False, B: 3 | End signals: False True
# Frame 474: | T: False, B: 2 | End signals: False True
# Frame 475: | T: False, B: 2 | End signals: False True
# Frame 476: | T: False, B: 2 | End signals: False True
# Frame 477: | T: False, B: 3 | End signals: False True
# Frame 478: | T: False, B: 3 | End signals: False True
# Frame 479: | T: False, B: 2 | End signals: False True
# Frame 480: | T: False, B: 4 | End signals: False True
# Frame 481: | T: False, B: 2 | End signals: False True
# Frame 482: | T: False, B: 2 | End signals: False True
# Frame 483: | T: False, B: 2 | End signals: False True
# Frame 484: | T: False, B: 2 | End signals: False True
# Frame 485: | T: False, B: 2 | End signals: False True
# Frame 486: | T: False, B: 2 | End signals: False True
# Frame 487: | T: False, B: 1 | End signals: False True
# Frame 488: | T: False, B: 2 | End signals: False True
# Frame 489: | T: False, B: 3 | End signals: False True
# Frame 490: | T: False, B: 3 | End signals: False True
# Frame 491: | T: False, B: 3 | End signals: False True
# Frame 492: | T: False, B: 3 | End signals: False True
# Frame 493: | T: False, B: 1 | End signals: False True
# Frame 494: | T: False, B: 2 | End signals: False True
# Frame 495: | T: False, B: 4 | End signals: False True
# Frame 496: | T: False, B: 3 | End signals: False True
# Frame 497: | T: False, B: 1 | End signals: False False
# Frame 498: | T: False, B: 3 | End signals: False False

# %%
import cv2
import numpy as np
import supervision as sv

# Define video information
video_info = sv.VideoInfo.from_video_path(source_path)

# Create VideoSink for output
import os
from datetime import datetime

original_name = source_path.split("/")[-1]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_filename = f"output_{file_name}_{timestamp}{file_extension}"

with sv.VideoSink(target_path=output_filename, video_info=video_info) as sink:
    cap = cv2.VideoCapture(source_path)
    in_play = False
    
    for frame_idx, ((toss_predictions, ball_predictions), (toss_result, ball_result), end_signal_1, end_signal_2) in enumerate(zip(results, zip(toss_results, ball_results), no_ball_end_signal, multiple_ball_end_signal)):
        ret, frame = cap.read()
        if not ret:
            break
        
        # Update in_play state
        if not in_play and toss_result:
            in_play = True
        elif in_play and (end_signal_1 or end_signal_2):
            in_play = False
        
        # Apply purple background with low opacity when in_play is true
        if in_play:
            overlay = frame.copy()
            cv2.rectangle(overlay, (0, 0), (frame.shape[1], frame.shape[0]), (128, 0, 128), -1)
            frame = cv2.addWeighted(overlay, 0.2, frame, 0.8, 0)
            
            # Add "In Play" text
            text = "In Play"
            font = cv2.FONT_HERSHEY_SIMPLEX
            text_size = cv2.getTextSize(text, font, 1, 2)[0]
            text_x = (frame.shape[1] - text_size[0]) // 2
            text_y = (frame.shape[0] + text_size[1]) // 2
            cv2.putText(frame, text, (text_x, text_y), font, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Add frame count to the bottom left of the window
        frame_count_text = f"Frame: {frame_idx + 1}"
        text_size = cv2.getTextSize(frame_count_text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)[0]
        cv2.putText(frame, frame_count_text, (10, frame.shape[0] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
        
        # Write the frame to the output video
        sink.write_frame(frame)
    
    cap.release()

print(f"Video processing complete. Output saved as '{output_filename}'")
# Out:
# Video processing complete. Output saved as 'output_demo_alt_10fps_20240815_085421.mp4'
